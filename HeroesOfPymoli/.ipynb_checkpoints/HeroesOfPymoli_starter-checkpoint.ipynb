# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np


# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
df = pd.read_csv(file_to_load)

# %%
df.head().style.format({"Price": "${:0,.2f}", })
# Out:
# <style  type="text/css" >
# </style><table id="T_7d39343a_bee9_11ea_8746_58ef68e7a8ed" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase ID</th>        <th class="col_heading level0 col1" >SN</th>        <th class="col_heading level0 col2" >Age</th>        <th class="col_heading level0 col3" >Gender</th>        <th class="col_heading level0 col4" >Item ID</th>        <th class="col_heading level0 col5" >Item Name</th>        <th class="col_heading level0 col6" >Price</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7d39343a_bee9_11ea_8746_58ef68e7a8edlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_7d39343a_bee9_11ea_8746_58ef68e7a8edrow0_col0" class="data row0 col0" >0</td>
#                         <td id="T_7d39343a_bee9_11ea_8746_58ef68e7a8edrow0_col1" class="data row0 col1" >Lisim78</td>
# ...

# %%
df.dtypes
# Out:
# Purchase ID      int64
# SN              object
# Age              int64
# Gender          object
# Item ID          int64
# Item Name       object
# Price          float64
# dtype: object

# %%
df['Price'].astype('int')
# Out:
# 0      3
# 1      1
# 2      4
# 3      3
# 4      1
#       ..
# 775    3
# 776    1
# 777    3
# 778    4
# 779    4
# Name: Price, Length: 780, dtype: int64

# %%
df.dtypes
# Out:
# Purchase ID      int64
# SN              object
# Age              int64
# Gender          object
# Item ID          int64
# Item Name       object
# Price          float64
# dtype: object

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
total_players = len(df["SN"].value_counts())

pd.DataFrame([total_players],columns = ["Total Players"])
# Out:
#    Total Players
# 0            576

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
unique_items = len(df["Item Name"].unique())
average_price = df["Price"].mean()
num_purchases = len(df["Purchase ID"].value_counts())
total_revenue = df["Price"].sum()

# %%
analysis = pd.DataFrame({"Unique Items": [unique_items],
              "Average Price": [average_price],
             "Number of Purchases": [num_purchases],
             "Total Revenue": [total_revenue]})

# %%
analysis["Average Price"]= analysis["Average Price"].map("${:.2f}".format)

# %%
analysis["Total Revenue"]= analysis["Total Revenue"].map("${:.2f}".format)

# %%
analysis
# Out:
#    Unique Items Average Price  Number of Purchases Total Revenue
# 0           179         $3.05                  780      $2379.77

# %% [markdown]
# ## Gender Demographics

# %%
gender_test = df[["SN", "Gender"]]

gender_test = gender_test.drop_duplicates()

# %%
gender_demographics_test = gender_test.groupby("Gender")

gender_demographics_test.count().head(10)

percentage = pd.DataFrame({'Percentage': df.groupby(('Gender')).size() / len(df)})
# Out:
#                        Percentage
# Gender
# Female                   0.144872
# Male                     0.835897
# Other / Non-Disclosed    0.019231

# %%
percentage_df = pd.crosstab(index=df['SN'], columns=df['Gender'])
print(percentage_df)
# Out:
# <bound method DataFrame.sum of Gender         Female  Male  Other / Non-Disclosed
# SN
# Adairialis76        0     1                      0
# Adastirin33         1     0                      0
# Aeda94              0     1                      0
# Aela59              0     1                      0
# Aelaria33           0     1                      0
# ...               ...   ...                    ...
# Yathecal82          3     0                      0
# Yathedeu43          0     2                      0
# Yoishirrala98       1     0                      0
# Zhisrisu83          0     2                      0
# Zontibe81           0     3                      0
#
# [576 rows x 3 columns]>

# %%
# Out:
#                        Percentage
# Gender
# Female                   0.144872
# Male                     0.835897
# Other / Non-Disclosed    0.019231

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
gender_demographics_test.describe()
# Out:
#                          SN
#                       count unique           top freq
# Gender
# Female                  113     81    Umolrian85    3
# Male                    652    484     Lisosia93    5
# Other / Non-Disclosed    15     11  Siarithria38    2

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
# Out:
#                       Purchase Count Average Purchase Price  \
# Gender
# Female                           113                  $3.20
# Male                             652                  $3.02
# Other / Non-Disclosed             15                  $3.35
#
#                       Total Purchase Value Avg Total Purchase per Person
# Gender
# Female                             $361.94                         $4.47
# Male                             $1,967.64                         $4.07
# Other / Non-Disclosed               $50.19                         $4.56

# %%
purchase_analysis = df.groupby(["Gender"])

# %%
purchase_value = purchase_analysis["Price"].sum()

# %%
purchase_count = purchase_analysis["Price"].count()

# %%
purchase_price = purchase_analysis["Price"].mean()

# %%
purchase_analysis_df = pd.DataFrame({"Purchase Count": purchase_count,
                                    "Average Purchase Price": purchase_price,
                                    "Total Purchase Value": purchase_value })

# %%
purchase_analysis_df.head()
# Out:
#                        Purchase Count  Average Purchase Price  \
# Gender
# Female                            113                3.203009
# Male                              652                3.017853
# Other / Non-Disclosed              15                3.346000
#
#                        Total Purchase Value
# Gender
# Female                               361.94
# Male                                1967.64
# Other / Non-Disclosed                 50.19

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
age_bins = [0, 9.90, 14.90, 19.90, 24.90, 29.90, 34.90, 39.90, 99999]
group_names = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]


df["Age Demographics"]= pd.cut(df["Age"], age_bins, labels=group_names)
demographic_group =df.groupby("Age Demographics")

df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price Age Demographics
# 0  Extraction, Quickblade Of Trembling Hands   3.53            20-24
# 1                          Frenzied Scimitar   1.56              40+
# 2                               Final Critic   4.88            20-24
# 3                                Blindscythe   3.27            20-24
# 4                                       Fury   1.44            20-24

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
# Out:
#            Purchase Count Average Purchase Price Total Purchase Value  \
# Age Ranges
# <10                    23                  $3.35               $77.13
# 10-14                  28                  $2.96               $82.78
# 15-19                 136                  $3.04              $412.89
# 20-24                 365                  $3.05            $1,114.06
# 25-29                 101                  $2.90              $293.00
# 30-34                  73                  $2.93              $214.00
# 35-39                  41                  $3.60              $147.67
# 40+                    13                  $2.94               $38.24
#
#            Avg Total Purchase per Person
# Age Ranges
# <10                                $4.54
# 10-14                              $3.76
# 15-19                              $3.86
# 20-24                              $4.32
# 25-29                              $3.81
# 30-34                              $4.12
# ...

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
top_spenders = df['Item ID'].groupby(df['SN']).count()


top_spenders= pd.DataFrame(data=top_spenders)
top_spenders.columns = ['Purchase Count']

top_spenders['Average Purchase Price'] = round(df['Price'].groupby(df['SN']).mean(),2)
top_spenders['Total Purchase Value'] = df['Price'].groupby(df['SN']).sum()


top_spenders.sort_values(by=['Total Purchase Value'], ascending=False, inplace=True)

top_spenders['Average Purchase Price'] = top_spenders['Average Purchase Price'].map('${:,.2f}'.format)
top_spenders['Total Purchase Value'] = top_spenders['Total Purchase Value'].map('${:,.2f}'.format)

top_spenders.head()
# Out:
#              Purchase Count Average Purchase Price Total Purchase Value
# SN
# Lisosia93                 5                  $3.79               $18.96
# Idastidru52               4                  $3.86               $15.45
# Chamjask73                3                  $4.61               $13.83
# Iral74                    4                  $3.40               $13.62
# Iskadarya95               3                  $4.37               $13.10

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
popular_items = df.groupby(['Item ID', 'Item Name','Price'])['Price'].agg(['count','sum'])
popular_items.columns = ['Purchase Count', 'Total Purchase Value']

popular_items.reset_index(inplace=True)
popular_items.set_index(['Item ID','Item Name'] ,inplace=True)

most_items = popular_items[['Purchase Count', 'Price', 'Total Purchase Value']]
most_popular_items = most_items.sort_values(by='Purchase Count', ascending=False)

most_popular_items['Price'] = most_popular_items['Price'].map('${:,.2f}'.format)
most_popular_items['Total Purchase Value'] = most_popular_items['Total Purchase Value'].map('${:,.2f}'.format)

most_popular_items.head()
# Out:
#                                                       Purchase Count  Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm              12  $4.23
# 108     Extraction, Quickblade Of Trembling Hands                  9  $3.53
# 145     Fiery Glass Crusader                                       9  $4.58
# 82      Nirvana                                                    9  $4.90
# 37      Shadow Strike, Glory of Ending Hope                        8  $3.16
#
#                                                      Total Purchase Value
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm               $50.76
# 108     Extraction, Quickblade Of Trembling Hands                  $31.77
# 145     Fiery Glass Crusader                                       $41.22
# 82      Nirvana                                                    $44.10
# 37      Shadow Strike, Glory of Ending Hope                        $25.28

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
profitable_items = most_popular_items.sort_values(by='Total Purchase Value', ascending=False)

# %%
profitable_items.head()
# Out:
#                                            Purchase Count  Price  \
# Item ID Item Name
# 63      Stormfury Mace                                  2  $4.99
# 29      Chaos, Ender of the End                         5  $1.98
# 173     Stormfury Longsword                             2  $4.93
# 1       Crucifer                                        3  $3.26
# 38      The Void, Vengeance of Dark Magic               4  $2.37
#
#                                           Total Purchase Value
# Item ID Item Name
# 63      Stormfury Mace                                   $9.98
# 29      Chaos, Ender of the End                          $9.90
# 173     Stormfury Longsword                              $9.86
# 1       Crucifer                                         $9.78
# 38      The Void, Vengeance of Dark Magic                $9.48
